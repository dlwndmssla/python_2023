# %%
N = int(input())
exam = set(map(int, input().split()))
M = int(input())
prac = set(map(int, input().split()))
exam2 = [0 for i in range(M)]
for i in range(M):
    for j in range(N):
        if [*prac][i] == [*exam][j]:
            exam2[i] = int(1)
            break
print(*exam2)
# Out:
# 1 1 0 0 0 1 1 0

# %%
#list의 시간복잡도는 O(n)이고 set의 시간복잡도는 O(1)이다.
import sys
sys.stdin.readline()

N = int(sys.stdin.readline())
exam = set(sys.stdin.readline().split())
M = int(sys.stdin.readline())
prac = set(sys.stdin.readline().split())
exam2 = []
for i in prac:
    print(i)
    if i in exam:
        exam2.append(1)
    else:
        exam2.append(0)
            
print(*exam2)
# Out:
# 2
# 3
# 4
# 5
# 9
# 10
# -10
# -5
# 1 1 0 0 0 1 1 0

# %%
import sys
sys.stdin.readline()

N = int(input())
set1 = set(sys.stdin.readline().split())

M = int(input())
set2 = set(sys.stdin.readline().split())

for i in M:
    if i in set1:    
        print(1, end = ' ')
    else:
        print(0, end = ' ')

# %%
import sys
str = int(sys.stdin.readline())

# %%
import sys

T = int(input())
for i in range(1,T+1):
    a,b = map(int, sys.stdin.readline().split())
    print(a+b)

# %%
import requests
import pprint
import lxml
import pandas as pd

from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

tradeYmd = '20220101'
#key = 'snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D'

url = f'https://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen?serviceKey=snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D&pageNo=1&numOfRows=196&dataType=xml&tradeYmd={tradeYmd}'
response = requests.get(url, params=params)
# xml 내용
content = response.text
# 깔끔한 출력 위한 코드
pp = pprint.PrettyPrinter(indent=4)
#print(pp.pprint(content))

# %%
date2022 = pd.read_csv('날짜파일.csv')
date = pd.DataFrame(date2022)

print(date)
# Out:
#        header
# 0    20210101
# 1    20210102
# 2    20210103
# 3    20210104
# 4    20210105
# ..        ...
# 603  20220827
# 604  20220828
# 605  20220829
# 606  20220830
# 607  20220831
#
# [608 rows x 1 columns]

# %%
발전량_df = []

for i in range(608):
    tradeYmd = int(date.iloc[i])

    
    url = f'https://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen?serviceKey=snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D&pageNo=1&numOfRows=196&dataType=xml&tradeYmd={tradeYmd}'
    #response = requests.get(url, params=params)
    response = url
    #print(response)    
    
    # xml 내용
    #content = response.text
    # 깔끔한 출력 위한 코드
    pp = pprint.PrettyPrinter(indent=4)
    
    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('item')
    #print(rows)

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]
    
    if i == 0:
        
        발전량_df = pd.DataFrame(row_list)

    else:
        
        발전량_df1 = pd.DataFrame(row_list)
        
    pd.concat([발전량_df, 발전량_df1])    
    print(발전량_df.info())
        
발전량_df = pd.DataFrame(row_list)
print(발전량_df.tail(20))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35172\2962089648.py in <module>
#      47         발전량_df1 = pd.DataFrame(row_list)
#      48
# ---> 49     pd.concat([발전량_df, 발전량_df1])
#      50     print(발전량_df.info())
#      51
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# ...

# %%
print(발전량_df.tail(20))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
k = pd.DataFrame()

for i in range(5):
    
    if i == 0:
        b = pd.DataFrame()
        
    else:
        k = pd.DataFrame(i)
        b.append(k)
        
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35172\1765215959.py in <module>
#       7
#       8     else:
# ----> 9         k = pd.DataFrame(i)
#      10         b.append(k)
#      11
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
# 모듈 import
import requests
import pprint


#url 입력

url = f'https://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen?serviceKey=snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D&pageNo=1&numOfRows=196&dataType=xml&tradeYmd={tradeYmd}'
params ={'endCreateDt' : '20220101' }

response = requests.get(url, params=params)

# xml 내용
content = response.text

# 깔끔한 출력 위한 코드
pp = pprint.PrettyPrinter(indent=4)
#print(pp.pprint(content))

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

# 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
row_list = [] # 행값
name_list = [] # 열이름값
value_list = [] #데이터값

# xml 안의 데이터 수집
for i in range(0, len(rows)):
    columns = rows[i].find_all()
    #첫째 행 데이터 수집
    for j in range(0,len(columns)):
        if i ==0:
            # 컬럼 이름 값 저장
            name_list.append(columns[j].name)
        # 컬럼의 각 데이터 값 저장
        value_list.append(columns[j].text)
    # 각 행의 value값 전체 저장
    row_list.append(value_list)
    # 데이터 리스트 값 초기화
    value_list=[]
    
#xml값 DataFrame으로 만들기
발전량_df = pd.DataFrame(row_list)
print(발전량_df)
# Out:
# [<item><tradeNo>01</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.336</amgo><rn>1</rn></item>, <item><tradeNo>02</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.141</amgo><rn>2</rn></item>, <item><tradeNo>03</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.774</amgo><rn>3</rn></item>, <item><tradeNo>04</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.921</amgo><rn>4</rn></item>, <item><tradeNo>05</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.017</amgo><rn>5</rn></item>, <item><tradeNo>06</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.578</amgo><rn>6</rn></item>, <item><tradeNo>07</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.696</amgo><rn>7</rn></item>, <item><tradeNo>08</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220831</tradeYmd><amgo>43.79</amgo><rn>8</rn></item>, <item><tradeNo>09</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20
# ...

# %%
# 모듈 import
import requests
import pprint


#url 입력

url = f'https://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen?serviceKey=snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D&pageNo=1&numOfRows=196&dataType=xml&tradeYmd={tradeYmd}'
params ={'endCreateDt' : '20220101' }

response = requests.get(url, params=params)

# xml 내용
content = response.text

# 깔끔한 출력 위한 코드
pp = pprint.PrettyPrinter(indent=4)
#print(pp.pprint(content))

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

# 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
row_list = [] # 행값
name_list = [] # 열이름값
value_list = [] #데이터값

# xml 안의 데이터 수집
for i in range(0, len(rows)):
    columns = rows[i].find_all()
    #첫째 행 데이터 수집
    for j in range(0,len(columns)):
        if i ==0:
            # 컬럼 이름 값 저장
            name_list.append(columns[j].name)
        # 컬럼의 각 데이터 값 저장
        value_list.append(columns[j].text)
    # 각 행의 value값 전체 저장
    row_list.append(value_list)
    # 데이터 리스트 값 초기화
    value_list=[]
    
#xml값 DataFrame으로 만들기
corona_df = pd.DataFrame(row_list)
print(corona_df.tail(19))
# Out:
# [<item><tradeNo>01</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>140.508</amgo><rn>1</rn></item>, <item><tradeNo>02</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>141.926</amgo><rn>2</rn></item>, <item><tradeNo>03</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>142.705</amgo><rn>3</rn></item>, <item><tradeNo>04</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>142.774</amgo><rn>4</rn></item>, <item><tradeNo>05</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>141.083</amgo><rn>5</rn></item>, <item><tradeNo>06</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>140.551</amgo><rn>6</rn></item>, <item><tradeNo>07</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>180.354</amgo><rn>7</rn></item>, <item><tradeNo>08</tradeNo><fuelTpCd>유전</fuelTpCd><tradeYmd>20220101</tradeYmd><amgo>194.362</amgo><rn>8</rn></item>, <item><tradeNo>09</tradeNo><fuelTpCd>유전</fuelTpCd><tr
# ...

# %%
# 모듈 import
import requests
import pprint


#url 입력

url = f'https://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen?serviceKey=snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D&pageNo=1&numOfRows=196&dataType=xml&tradeYmd={tradeYmd}'
params ={'endCreateDt' : '20220101' }

response = requests.get(url, params=params)

# xml 내용
content = response.text

# 깔끔한 출력 위한 코드
pp = pprint.PrettyPrinter(indent=4)
#print(pp.pprint(content))

xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
rows = xml_obj.findAll('item')
print(rows)

# 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
row_list = [] # 행값
name_list = [] # 열이름값
value_list = [] #데이터값

# xml 안의 데이터 수집
for i in range(0, len(rows)):
    columns = rows[i].find_all()
    #첫째 행 데이터 수집
    for j in range(0,len(columns)):
        if i ==0:
            # 컬럼 이름 값 저장
            name_list.append(columns[j].name)
        # 컬럼의 각 데이터 값 저장
        value_list.append(columns[j].text)
    # 각 행의 value값 전체 저장
    row_list.append(value_list)
    # 데이터 리스트 값 초기화
    value_list=[]
    
#xml값 DataFrame으로 만들기
corona_df = pd.DataFrame(row_list)
print(corona_df.tail(19))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 모듈 import
import requests
import pprint

for i in range(608):
    #url 입력

    url = f'https://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen?serviceKey=snRlxbFqrdJSeQA0CIAQqhPIJllIKY7wJr25IWmM%2BkFS66XjhT5Y5QHP8%2BIpD9BRaiG5fsXNlw9KRbwfjDhGUA%3D%3D&pageNo=1&numOfRows=192&dataType=xml&tradeYmd={params}'
    params = '20220101'

    response = requests.get(url, params=params)

    # xml 내용
    content = response.text

    # 깔끔한 출력 위한 코드
    pp = pprint.PrettyPrinter(indent=4)
    #print(pp.pprint(content))

    xml_obj = bs4.BeautifulSoup(content,'lxml-xml')
    rows = xml_obj.findAll('item')
    #print(rows)

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]
        
    if i == 0:
        
        발전량_df = pd.DataFrame(row_list, columns=name_list)

    else:
        
        발전량_df1 = pd.DataFrame(row_list, columns=name_list)
        발전량_df.append(발전량_df1)
        
발전량_df = pd.DataFrame(row_list)
print(발전량_df.tail(20))
# Out:
# []
# ...
